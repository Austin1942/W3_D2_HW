# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "http://ergast.com/api/f1/2008/5/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
def get_racer_info(data):
    new_data=[]
    for racer in data:
        racer_dict = {}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        print(racer_name)
        racer_dict[racer_name]={
            'first_name':racer['Driver']['givenName'],
            'last_name': racer['Driver']['familyName'],
            'position': racer['position'],
            'wins':racer['wins'],
            'DOB':racer['Driver']['dateOfBirth'],
            'nationality':racer['Driver']['nationality'],
            'contructor':racer['Constructors'][0]['name']
        
        }
        new_data.append(racer_dict)
    return new_data


get_racer_info(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-5a02df550061> in <module>
#      19
#      20
# ---> 21 get_racer_info(data)
#
# NameError: name 'data' is not defined

# %%
def get_driver(year,r):
    url = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
    #if not response.ok:
    if response.json()['Mrdata']['StandingsTable']['StandingsLists']:
# Out:
#   File "<ipython-input-10-01e09e97424a>", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
pokemon_1 = "https://pokeapi.co/api/v2/pokemon/charizard"
pokemon_2 = "https://pokeapi.co/api/v2/pokemon/gengar"
pokemon_3 = "https://pokeapi.co/api/v2/pokemon/feraligatr"
pokemon_4 = "https://pokeapi.co/api/v2/pokemon/pidgeot"
pokemon_5 = "https://pokeapi.co/api/v2/pokemon/nidoking"



char_q = requests.get(pokemon_1)
gen_q = requests.get(pokemon_2)
free_q = requests.get(pokemon_3)
pigy_q = requests.get(pokemon_4)
nido_q = requests.get(pokemon_5)



char_dex = "The Flame Pokémon. Charizard's powerful flame can melt absolutely anything. "

gen_dex = "The Shadow Pokémon. The evolved form of Haunter. Details about Gengar are unknown."

free_dex = "This Pokémon intimidates its foes by opening its huge mouth. In battle, it will kick the\nground hard with its thick and powerful hind legs to charge at the foe at an incredible speed."

pigy_dex = "This Pokémon flies at Mach 2 speed, seeking prey. Its large talons are feared as wicked weapons."

nido_dex = "The Drill Pokémon. Nidoking swings its large tail about to create distance,\nthen charges in with the full force of its body behind it."




def pokemon():
    charizard_dict ={
        char_q.json()['forms'][0]['name']:char_dex,
        "ability":char_q.json()['abilities'][0]['ability']['name'],
        "Base XP":char_q.json()['base_experience'],
        "Appearance":char_q.json()['sprites']['front_shiny']
        }
    for y, x in charizard_dict.items():
        print(y, x)
    gengar_dict ={
         gen_q.json()['forms'][0]['name']:gen_dex,
        "ability":gen_q.json()['abilities'][0]['ability']['name'],
        "Base XP":gen_q.json()['base_experience'],
        "Appearance":gen_q.json()['sprites']['front_shiny']
    }
    for y, x in gengar_dict.items():
        print(y, x)
    feraligatr_dict ={
         free_q.json()['forms'][0]['name']:free_dex,
        "ability":free_q.json()['abilities'][0]['ability']['name'],
        "Base XP":free_q.json()['base_experience'],
        "Appearance":free_q.json()['sprites']['front_shiny']
    }
    for y, x in feraligatr_dict.items():
        print(y, x)
    pidgeot_dict = {
         pigy_q.json()['forms'][0]['name']:pigy_dex,
        "ability":pigy_q.json()['abilities'][0]['ability']['name'],
        "Base XP":pigy_q.json()['base_experience'],
        "Appearance":pigy_q.json()['sprites']['front_shiny']
    }
    for y, x in pidgeot_dict.items():
        print(y, x)
    nidoking_dict = {
         nido_q.json()['forms'][0]['name']:nido_dex,
        "ability":nido_q.json()['abilities'][0]['ability']['name'],
        "Base XP":nido_q.json()['base_experience'],
        "Appearance":nido_q.json()['sprites']['front_shiny']
    }
    for y, x in nidoking_dict.items():
        print(y, x)

pokemon()
# Out:
# charizard The Flame Pokémon. Charizard's powerful flame can melt absolutely anything.
# ability blaze
# Base XP 240
# Appearance https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png
# gengar The Shadow Pokémon. The evolved form of Haunter. Details about Gengar are unknown.
# ability cursed-body
# Base XP 225
# Appearance https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/94.png
# feraligatr This Pokémon intimidates its foes by opening its huge mouth. In battle, it will kick the
# ground hard with its thick and powerful hind legs to charge at the foe at an incredible speed.
# ability torrent
# Base XP 239
# Appearance https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/160.png
# pidgeot This Pokémon flies at Mach 2 speed, seeking prey. Its large talons are feared as wicked weapons.
# ability keen-eye
# Base XP 216
# ...
